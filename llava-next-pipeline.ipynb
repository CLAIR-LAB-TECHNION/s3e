# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")

from llava_next_utils import LlavaOVModel
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# MODEL = "lmms-lab/llava-onevision-qwen2-0.5b-si"
# MODEL = "lmms-lab/llava-onevision-qwen2-7b-ov"
MODEL = "lmms-lab/llava-onevision-qwen2-7b-si"
# MODEL = "lmms-lab/llava-onevision-qwen2-72b-si"

system = """You will be asked a yes-no question about an image. Your job is to answer truthfully with a single "yes" or "no" and no other text."""

vqa = LlavaOVModel(MODEL, system)
# Out:
# Loaded LLaVA model: lmms-lab/llava-onevision-qwen2-7b-si
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# You are using a model of type llava to instantiate a model of type llava_qwen. This is not supported for all configurations of models and can yield errors.
# Loading vision tower: google/siglip-so400m-patch14-384
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Model Class: LlavaQwenForCausalLM

# %%
from PIL import Image

start = Image.open('examples/groceries_world/start.png')
hmilk = Image.open('examples/groceries_world/holding_milk.png')
hcereal = Image.open('examples/groceries_world/holding_cereal.png')
milkc = Image.open('examples/groceries_world/milk_in_container.png')
cerealc = Image.open('examples/groceries_world/cereal_in_container.png')

# %%
Q = "Is the red box of cereal in the dark wook container?"
probs1 = vqa([start], Q, get_probs=True)
# probs2 = vqa([hmilk], Q, get_probs=True)
# probs3 = vqa([milkc], Q, get_probs=True)
# probs4 = vqa([hcereal], Q, get_probs=True)
# probs5 = vqa([cerealc], Q, get_probs=True)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[5], line 2
#       1 Q = "Is the red box of cereal in the dark wook container?"
# ----> 2 probs1 = vqa([start], Q, get_probs=True)
#       3 # probs2 = vqa([hmilk], Q, get_probs=True)
#       4 # probs3 = vqa([milkc], Q, get_probs=True)
#       5 # probs4 = vqa([hcereal], Q, get_probs=True)
#       6 # probs5 = vqa([cerealc], Q, get_probs=True)
#
# File ~/workspace/semantic_state_estimator/llava_next_utils.py:63, in LlavaOVModel.__call__(self, images, query, get_probs)
#      61 if get_probs:
#      62     with torch.inference_mode():
# ---> 63         outputs = self.model.forward(input_ids,
#      64                                 images=image_tensor,
#      65                                 image_sizes=image_sizes,
#      66                                 use_cache=True)
# ...

# %%
yes_tokens = list(map(lambda x: x[0], vqa.tokenizer(['yes', 'YES', 'Yes'])['input_ids']))
no_tokens = list(map(lambda x: x[0], vqa.tokenizer(['no', 'NO', 'No'])['input_ids']))

# %%
def get_yes_probs(probs):
    yes = probs[0, -1, yes_tokens].sum().item()
    no = probs[0, -1, no_tokens].sum().item()
    return yes / (yes + no)

p1 = get_yes_probs(probs1)
p2 = get_yes_probs(probs2)
p3 = get_yes_probs(probs3)
p4 = get_yes_probs(probs4)
p5 = get_yes_probs(probs5)

p1, p2, p3, p4, p5
